# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
from IPython.display import display
import time
from scipy import stats
import hashlib

NUM_PHONES= 4

# %%
def get_data(filename):
    start = time.time()
    df1 = pd.read_csv(filename, sep='\t')
    df1 = df1.set_axis(["ATime", "Channel", "Signal", "Source", "Dest", "Seq", "SSID", "BSSID"], axis=1)

    df1["RTime"] = 0
    df1["Tag"] = "X"
    
    

    df1 = df1.drop(["SSID", "BSSID"], axis=1)
    freq_map = {2412: 1, 2437: 6, 2462: 11}
    df1 = df1.replace({"Channel": freq_map})
    
    # df1 = df1[0:1000000]

    for i in range(1, len(df1)):
        df1.loc[i, "Tag"] = str(df1.loc[i - 1, "Channel"]) + "->" + str(df1.loc[i, "Channel"])
        df1.loc[i, "CType"] = "Same" if str(df1.loc[i - 1, "Channel"])  == str(df1.loc[i, "Channel"]) else "Different"
        df1.loc[i, "RTime"] = df1.loc[i, "ATime"] - df1.loc[i - 1, "ATime"]

    df1 = df1.iloc[1:, :]

    df1 = df1.astype({"ATime": np.float32, "RTime": np.float32, "Signal": np.float32})

    end = time.time()
    print("Total Time: ", end - start)
    
    return df1

# %%
# get the data
df1 = get_data("../data/text/sample21.txt")
df2 = get_data("../data/text/sample22.txt")
df3 = get_data("../data/text/sample23.txt")
# Out:
# Total Time:  484.54511642456055
# Total Time:  467.6997570991516
# Total Time:  124.57485389709473

# %%
df3["Time"] = df3["ATime"] - df3["ATime"].iloc[0]
df3 = df3[(df3.Source == "e8:50:8b:43:b1:20") | (df3.Source =="a8:86:60:da:7d:7b")].sort_values(by="Time")
df3["Phone"] = 4
switch = list(df3[df3.Source == "e8:50:8b:43:b1:20"].index)
df3.loc[switch, "Phone"] = 3

# %% [markdown]
# First, we need to make sure we keep only the packets that we are interested in. We'll do this by looking for the MAC address that occurs the most frequently nearby the network cards.

# %%
print("Phone 1")
print("#" * 20)
display(df1[df1.Signal > -45].groupby("Source").size().sort_values(ascending=False))
print("#" * 20)
print("Phone 2")
print("#" * 20)
display(df2[df2.Signal > -45].groupby("Source").size().sort_values(ascending=False))
# Out:
# Phone 1
# ####################
# Source
# e8:50:8b:43:b1:20    52207
# d1:a1:16:87:62:41       55
# 1a:d0:b9:35:30:d1       10
# e8:50:ab:51:b1:20        6
# 74:a8:c5:a1:58:90        5
#                      ...
# 99:1a:ab:80:15:49        1
# 99:a1:16:87:62:c1        1
# 9a:52:0a:a2:62:41        1
# 9a:54:15:84:f0:ff        1
# fe:50:8b:03:84:68        1
# Length: 719, dtype: int64
# ####################
# Phone 2
# ####################
# Source
# a8:86:60:da:7d:7b    367820
# a9:86:60:da:7d:7b        67
# fc:01:7c:88:dc:af        48
# 64:c8:7f:26:6e:bb        35
# ec:84:60:da:7d:7b        28
#                       ...
# 65:c8:7f:26:ff:bb         1
# 65:c8:7f:66:5a:b2         1
# 65:c8:7f:66:78:7b         1
# 65:c8:7f:8c:59:7b         1
# ff:ff:7f:b7:6e:bb         1
# Length: 2922, dtype: int64

# %% [markdown]
# Let's see what the summary statistics for each phone looks like:

# %%
df1 = df1[df1.Source == "e8:50:8b:43:b1:20"].iloc[0:100000]
df2 = df2[df2.Source == "a8:86:60:da:7d:7b"].iloc[0:100000]

df1["Phone"] = 1
df2["Phone"] = 2

df1["Time"] = df1["ATime"] - df1["ATime"].iloc[0]
df2["Time"] = df2["ATime"] - df2["ATime"].iloc[0]

df = pd.concat([df1, df2, df3])
display(df)
# Out:
#                ATime  Channel  Signal             Source               Dest  \
# 334     1.667419e+09        1   -57.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 336     1.667419e+09        1   -57.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 337     1.667419e+09        1   -56.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 339     1.667419e+09        1   -55.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 340     1.667419e+09        1   -56.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# ...              ...      ...     ...                ...                ...
# 593043  1.668522e+09        1   -77.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 593042  1.668522e+09        6   -34.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 593041  1.668522e+09        1   -78.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 593051  1.668522e+09        6   -33.0  e8:50:8b:43:b1:20  ff:ff:ff:ff:ff:ff
# 593264  1.668522e+09       11   -37.0  a8:86:60:da:7d:7b  ff:ff:ff:ff:ff:ff
#
#            Seq     RTime    Tag      CType  Phone     Time
# 334     1176.0  0.090282   6->1  Different      1      0.0
# 336     1177.0  0.000486   6->1  Different      1      0.0
# 337     1178.0  0.002232   1->1       Same      1      0.0
# 339     1179.0  0.015008   1->1       Same      1      0.0
# 340     1180.0  0.002451   1->1       Same      1      0.0
# ...        ...       ...    ...        ...    ...      ...
# 593043  2785.0  0.001410   6->1  Different      3  75392.0
# 593042  2784.0  0.000019   1->6  Different      3  75392.0
# 593041  2784.0  0.037778   6->1  Different      3  75392.0
# 593051  2789.0  0.000019   1->6  Different      3  75392.0
# 593264  3629.0  0.000015  6->11  Different      4  75392.0
#
# [295811 rows x 11 columns]

# %% [markdown]
# Let's try taking 10000 samples and seeing if there is a preference in channel by phone:

# %%
df[["Phone", "Tag", "RTime"]].groupby(["Tag", "Phone"]).describe()


ft = df.sort_values("Time").groupby("Phone").apply(lambda x: x.sample(10000))
ft = ft.reset_index(drop=True)
# display(ft.groupby(["Tag", "Phone"]).size())
# display(ft.groupby(["Phone", "Tag"]).size())
# Out:
# Phone  Tag
# 1      11->6       22
# 3      11->6       99
#        1->11      110
# 1      1->11      152
#        6->11      173
# 3      11->1      180
# 4      11->6      241
# 1      11->1      244
# 3      6->11      314
# 2      1->6       524
# 4      6->11      528
# 1      6->6       573
# 2      6->1       611
# 4      1->11      790
# 2      11->6      814
#        6->11      886
# 4      6->1       910
#        11->1      936
# 3      1->6       937
# 4      1->6       948
# 3      6->1       952
# 2      11->11     988
#        11->1     1177
# 4      11->11    1256
# 2      1->11     1312
#        1->1      1634
# 4      1->1      1783
# 1      1->1      1791
# 2      6->6      2054
# 3      1->1      2280
# 1      11->11    2296
# 3      11->11    2340
# 1      1->6      2357
#        6->1      2392
# 4      6->6      2608
# 3      6->6      2788
# dtype: int64

# %%
short = df.loc[df["RTime"] < 0.3, ["RTime", "CType", "Phone"]]
g = sns.FacetGrid(short, col="CType", sharey=True, sharex=True, row="Phone")
g.map(sns.histplot, "RTime", binwidth = 0.02, stat="density")
g.figure.set_size_inches(14, 8)

for ax in g.axes.flat:
    ax.set_xticks(np.arange(0, 0.3, 0.02)) # <--- set the ticks first
plt.show()

# %%
ds = df[df.RTime < 0.5].sort_values(by="Time")
sns.violinplot(ds, x="CType", y="RTime", hue="Phone")
plt.show()

# %%
sns.displot(df[df.RTime < 0.3], x="RTime", hue="Phone", common_bins=True, bins=10, palette="deep", binwidth=0.05).set(title="Interarrival times under 0.3 seconds")
plt.show()

# %% [markdown]
# Let's take a look at the CDFs:

# %%
sns.displot(df[df.RTime < 0.4], x="RTime", col="CType", hue="Phone", kind="ecdf", palette="deep")
plt.show()

# %% [markdown]
# There appears to be more variance iwhen switching channels. Given that phones 1/3 and 2/4 are the same, we expect their CDFs to be roughly the same. This appears to be more true when we do not swithc channels. Let's try the KS test on each distribution (same channel probe or different channel probe):

# %%
ks = []
for dist in ["Same", "Different"]:
    for phone1 in range(1,NUM_PHONES,1):
        for phone2 in range(phone1+1, NUM_PHONES + 1, 1):
            ls = df[(df.Phone == phone1) & (df.CType == dist)]["RTime"]
            rs = df[(df.Phone == phone2) & (df.CType == dist)]["RTime"]
            x = stats.kstest(ls, rs)
            ks.append([phone1, phone2, x[0], x[1]])
            

ks = DataFrame(ks, columns=["Phone1", "Phone2", "Stat", "pValue"])
display(ks)
# Out:
#     Phone1  Phone2      Stat         pValue
# 0        1       2  0.476616   0.000000e+00
# 1        1       3  0.033948   1.355853e-14
# 2        1       4  0.475137   0.000000e+00
# 3        2       3  0.503442   0.000000e+00
# 4        2       4  0.038866   1.992415e-28
# 5        3       4  0.502172   0.000000e+00
# 6        1       2  0.357964   0.000000e+00
# 7        1       3  0.305753   0.000000e+00
# 8        1       4  0.400580   0.000000e+00
# 9        2       3  0.238381  3.441680e-315
# 10       2       4  0.116036  2.821813e-222
# 11       3       4  0.272961   0.000000e+00

# %% [markdown]
# Since the P values are approximately 0, it appears that we should be able to classify a pair of packets based on the interarrival time. Since the interarrival time for two packets on the same channel approaches 0, we will end up using the interarrival time between two packets that are on different chanels.

# %%
df[df.CType == "Different"].loc[:, ["Phone", "RTime"]].groupby("Phone").describe()
# Out:
#          RTime                                                              \
#          count      mean       std       min       25%       50%       75%
# Phone
# 1      53888.0  0.058153  0.508629  0.000005  0.000018  0.001356  0.003084
# 2      52520.0  0.103555  0.388090  0.000008  0.000020  0.002555  0.064226
# 3       7151.0  0.097584  0.429732  0.000010  0.000020  0.001902  0.038357
# 4      29549.0  0.152265  0.531655  0.000010  0.000020  0.026923  0.102797
#
#
#              max
# Phone
# 1      23.398966
# 2      12.143442
# 3       6.554741
# 4      10.347971

# %%
for i in range(1, NUM_PHONES + 1, 1):
    mean = df.loc[df.Phone == i, "RTime"].mean()
    std = df.loc[df.Phone == i, "RTime"].std()
    
    print(f"Variance to Mean ratio for phone {i} is {std**2/mean}")
# Out:
# Variance to Mean ratio for phone 1 is 3.4094306184911525
# Variance to Mean ratio for phone 2 is 1.2360078351615373
# Variance to Mean ratio for phone 3 is 1.4287386156512871
# Variance to Mean ratio for phone 4 is 1.5387759032073363

# %%
def to_local(string):
    try:
        x = bytearray(string, encoding="ascii")[1]
    except:
        return True
    
    y = (x >> 1) & 1
    return y == 1
    
df["Random"] = df["Source"].str[0:2].map(to_local)

# %%
def hash_string(string):
    x = string.encode("ascii")
    y = hashlib.md5(x)
    return y.hexdigest()
    
# df["Source"] = df["Source"].map(hash_string)
